# %%
from google_play_scraper import app, reviews, Sort, reviews_all

import pandas as pd
import numpy as np
seed = 0
np.random.seed(seed)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

import datetime as dt
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

from wordcloud import WordCloud

import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Scrapping
from google_play_scraper import app, reviews_all, Sort

scrapreview, _ = reviews(
    'id.bmri.livin',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count= 10000
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df
# Out:
#                                   reviewId              userName  \
# 0     1e5a576a-149e-4002-a66a-f16aebae9900       Pengguna Google
# 1     4bd721f2-8652-4b69-b8ce-aac2be476891       Pengguna Google
# 2     6452d916-c1de-4808-bf02-dffcb21bba2e       Pengguna Google
# 3     f0286054-5577-4cc3-bc9c-cd143e50695e       Pengguna Google
# 4     e6d00fef-4724-4778-aa85-e2b0a78eed4f       Pengguna Google
# ...                                    ...                   ...
# 9995  a50461e0-090e-414e-b686-1b745ab61617              Ahmad 88
# 9996  c8881e9b-7e6c-4d29-af37-466b1dfc575c  Prengki Wildanattaqi
# 9997  1c35fbbb-5de2-4db2-a68f-5e4ff149974a            Fandy Nteu
# 9998  01b9c30d-30ab-4487-97fd-32edf0dc58e1                Noir F
# 9999  4f8ac48b-f0ab-41e9-9e01-e27478a33694           JNE Kautsar
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 9995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0     Buka rekening Mandiri lewat aplikasi ini katan...      1            579
# 1     livin sekarang tidak support jika setting akse...      1            394
# 2     mau login , harus masukkan nomor kartu debit !...      1            346
# 3     buat buka aja susah amat,, lama bgt loading ny...      1            130
# 4     ini kenapa Livin nya GK bsa dibuka...tiap buka...      2              3
# ...                                                 ...    ...            ...
# 9995  Bungga deposito mandiri kecil bangat jauh lebi...      2              0
# 9996  Upgrade uda 2 hari gx bisa2..ja5Ingan bagus..b...      1              0
# 9997  Aplikasi taik, tidak jelas aktivasinya, sudah ...      1              0
# 9998  Ini livin ngapain ya, kok cek pengaturan jam o...      1              1
# 9999  Aplikasi nya mudah banget digunakan. Fiturnya ...      5              0
#
#      reviewCreatedVersion                  at  \
# 0                   3.1.0 2025-08-31 05:41:33
# 1                   3.1.0 2025-09-09 12:08:00
# 2                   3.1.0 2025-09-12 09:57:06
# 3                   3.1.0 2025-10-03 16:38:06
# 4                   3.1.0 2025-10-20 00:10:08
# ...                   ...                 ...
# 9995                1.6.0 2023-10-30 06:05:57
# 9996                1.0.2 2022-07-07 18:50:55
# 9997                1.3.0 2023-04-22 16:49:02
# 9998                1.1.0 2022-06-15 15:22:54
# 9999                1.0.2 2022-05-31 08:05:50
#
#                                            replyContent           repliedAt  \
# 0     Hi Sahabat @Triana Wulandari Yueliang85, mohon... 2025-08-31 05:59:19
# 1     Halo Sahabat @Izzy F., mohon maaf atas ketidak... 2025-09-09 12:11:14
# 2     Hai Sahabat @Erwindo Setyawan, mohon maaf atas... 2025-09-12 10:40:08
# 3     Hai Sahabat @Deonn Oblet, mohon maaf atas keti... 2025-10-03 16:43:17
# 4     Halo Sahabat @DANIA NANDA, mohon maaf atas ket... 2025-10-20 00:11:59
# ...                                                 ...                 ...
# 9995  Halo Sahabat @Ahmad 88, mohon maaf atas ketida... 2023-10-30 06:36:52
# 9996  Halo Bpk Prengki, mohon maaf atas ketidaknyama... 2022-07-06 18:20:23
# 9997  Halo Bpk Fandy, mohon maaf atas ketidaknyamana... 2023-04-22 16:55:14
# 9998  Hai Bpk Noir. Mohon maaf atas ketidaknyamanann... 2022-06-15 20:36:55
# 9999  Halo Bpk/Ibu, terima kasih review yang diberik... 2022-06-08 13:50:38
#
#      appVersion
# 0         3.1.0
# 1         3.1.0
# 2         3.1.0
# 3         3.1.0
# 4         3.1.0
# ...         ...
# 9995      1.6.0
# 9996      1.0.2
# 9997      1.3.0
# 9998      1.1.0
# 9999      1.0.2
#
# [10000 rows x 11 columns]

# %%
# Menyimpan ulasan dalam file CSV
import csv
app_reviews_df.to_csv('Ulasan_LivinbyMandiri.csv', index=False)
